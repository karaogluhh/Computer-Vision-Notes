# %% [markdown]
# <a href="https://colab.research.google.com/github/karaogluhh/Computer-Vision-Notes/blob/main/OpenCV_Official_Tutorials_Core_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
im = cv2.imread("butterfly.png")
cv2_imshow(im)
cv2.waitKey(1)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>
# -1

# %%
(w, h, ch) = im.shape
print(f"Weight:{w}, Height:{h}, Channel:{ch}")
# Out:
# Weight:256, Height:256, Channel:3

# %%
im.dtype
# Out:
# dtype('uint8')

# %%
im.size
# Out:
# 196608

# %%
print(f"The first 10 x 10 values for blue channel are \n {im[:10, :10, 0]}\n\n")
print(f"The first 10 x 10 values for green channel are \n {im[:10, :10, 1]}\n\n")
print(f"The first 10 x 10 values for red channel are \n {im[:10, :10, 2]}\n\n")
# Out:
# The first 10 x 10 values for blue channel are
#  [[74 74 74 74 73 77 79 80 83 85]
#  [75 74 74 72 74 77 76 79 81 85]
#  [73 75 74 74 74 81 80 83 81 86]
#  [74 74 72 76 73 79 80 83 80 84]
#  [75 74 70 76 74 75 79 78 81 84]
#  [74 73 74 74 74 76 76 78 80 80]
#  [72 74 74 74 73 75 76 78 81 80]
#  [69 74 74 68 70 73 75 77 79 77]
#  [72 71 72 75 73 75 74 75 76 74]
#  [72 71 73 73 74 74 70 74 72 74]]
#
#
# The first 10 x 10 values for green channel are
#  [[103 102 105 100  98  99  99  98  97  96]
#  [104 102 105  98  99  99  97  96  96  96]
#  [101 103 101  98  98 101  98  97  93  93]
#  [103 102  98  99  96  99  98  97  91  91]
#  [103  99  95  99  98  96  96  92  92  91]
#  [102  97  98  98  98  97  93  92  90  88]
#  [ 99  98  98  97  95  95  93  92  92  88]
#  [ 97  99  98  91  92  92  92  90  90  84]
#  [ 99  96  93  93  90  90  89  87  87  80]
#  [ 99  96  95  91  89  88  84  85  82  80]]
#
#
# The first 10 x 10 values for red channel are
# ...

# %%
sample_blue_pix = im[10, 10, 0]
sample_green_pix = im[20, 20, 1]
sample_red_pix = im[30, 30, 2]

# %%
print(im[10, 10])
# Out:
# [ 74  79 151]

# %%
print(im[10, 10, :])
# Out:
# [ 74  79 151]

# %%
roi = im[10: 90, 20:150]
cv2_imshow(roi)
# Out:
# <PIL.Image.Image image mode=RGB size=130x80>

# %%
b, g, r = cv2.split(im)
im_ = cv2.merge((b, g, r))
cv2_imshow(im_)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
im[:,:,1] = 0
cv2_imshow(im)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %% [markdown]
# ## Image Padding
# - `cv2.copyMakeBorder()`

# %%
BLUE = [255, 0, 0]

logo = cv2.imread('opencv_logo.png')

replicate = cv2.copyMakeBorder(logo, 10, 10, 10, 10, cv2.BORDER_REPLICATE)
reflect = cv2.copyMakeBorder(logo, 10, 10, 10, 10, cv2.BORDER_REFLECT)
reflect101 = cv2.copyMakeBorder(logo, 10, 10, 10, 10, cv2.BORDER_REFLECT_101)
wrap = cv2.copyMakeBorder(logo, 10, 10, 10, 10, cv2.BORDER_WRAP)
constant = cv2.copyMakeBorder(logo, 10, 10, 10, 10, cv2.BORDER_CONSTANT, value=BLUE)


plt.subplot(231),plt.imshow(logo,'gray'),plt.title('ORIGINAL')
plt.subplot(232),plt.imshow(replicate,'gray'),plt.title('REPLICATE')
plt.subplot(233),plt.imshow(reflect,'gray'),plt.title('REFLECT')
plt.subplot(234),plt.imshow(reflect101,'gray'),plt.title('REFLECT_101')
plt.subplot(235),plt.imshow(wrap,'gray'),plt.title('WRAP')
plt.subplot(236),plt.imshow(constant,'gray'),plt.title('CONSTANT')

plt.show()

# %% [markdown]
# ## Image Addition

# %%
x = np.uint8([250])
y = np.uint8([10])

print(cv2.add(x, y))
# Out:
# [[260.]
#  [  0.]
#  [  0.]
#  [  0.]]

# %%
print(x + y)
# Out:
# [4]
